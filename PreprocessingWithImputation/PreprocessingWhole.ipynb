# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("wholedata.csv")
data.head()
data.shape
# Out:
# (325, 33)

# %%
# data formatting
data=data.replace("-",np.nan)
data=data.replace("0",np.nan)
data=data.replace(">99",99)
data.head()
# Out:
#           country          RSA rural water supply urban water supply  \
# 0     Afghanistan  62.26143773        57.32129212        95.90874286
# 1         Albania  98.28801438        89.87517388         91.8354214
# 2         Algeria  89.67236867        88.69095651        95.44293244
# 3  American Samoa          NaN                NaN                NaN
# 4         Andorra           99                 99                 99
#
#             ARA      Health  2018 EPI SCORE  Rural population (1000 inhab)  \
# 0   2.730664253  694.109542           37.74                      26558.609
# 1  -0.265874296    2.511507           65.46                       1190.155
# 2   0.073382147  137.442788           57.18                      11547.532
# 3           NaN         NaN             NaN                            NaN
# 4           NaN         NaN             NaN                          9.120
#
#    Urban population (1000 inhab)  Population density (inhab/km2)_x  ...  \
# 0                       8971.472                         55.595553  ...
# 1                       1740.032                        104.008979  ...
# 2                      29770.610                         17.377711  ...
# 3                            NaN                               NaN  ...
# 4                         67.845                        163.831915  ...
#
#    Agricultural water withdrawal (10^9 m3/year)  \
# 0                                        20.000
# 1                                         0.905
# 2                                         6.671
# 3                                           NaN
# 4                                           NaN
#
#    Industrial water withdrawal (km<sup>3</sup>/year or 10<sup>9</sup>m<sup>3</sup>/year)  \
# 0                                             0.1695
# 1                                             0.2318
# 2                                             0.1910
# 3                                                NaN
# 4                                                NaN
#
#    Municipal water withdrawal (km<sup>3</sup>/year or 10<sup>9</sup>m<sup>3</sup>/year)  \
# 0                                             0.2034
# 1                                             0.2830
# 2                                             3.6000
# 3                                                NaN
# 4                                                NaN
#
#    Total water withdrawal per capita (m<sup>3</sup>/year per inhabitant)  \
# 0                                         561.297018
# 1                                         492.273511
# 2                                         252.771321
# 3                                                NaN
# 4                                                NaN
#
#    MDG 7.5. Freshwater withdrawal as % of total renewable water resources (%)  \
# 0                                          31.045461
# 1                                           3.933775
# 2                                          84.014742
# 3                                                NaN
# 4                                                NaN
#
#    SDG 6.4.2. Water Stress (%)  SDG 6.4.1. Water Use Efficiency (US$/m3)_y  \
# 0                    54.757019                                    0.923778
# 1                     7.139423                                    6.656907
# 2                   137.920360                                   14.354620
# 3                          NaN                                         NaN
# 4                          NaN                                         NaN
#
#    Resilience and securityStorage   water productivity(industry)  \
# 0                          2.00900                      1.022643
# 1                          4.03000                     11.765478
# 2                          8.61925                     20.235979
# 3                              NaN                           NaN
# 4                              NaN                           NaN
#
#    water productivity(Total agricultural production_US$)
# 0                                       4.500000e+09
# 1                                       2.310000e+09
# 2                                       6.080000e+10
# 3                                                NaN
# 4                                       2.560000e+08
#
# [5 rows x 33 columns]

# %%
data.dtypes
# Out:
# country                                                                                   object
# RSA                                                                                       object
# rural water supply                                                                        object
# urban water supply                                                                        object
# ARA                                                                                       object
# Health                                                                                   float64
# 2018 EPI SCORE                                                                           float64
# Rural population (1000 inhab)                                                            float64
# Urban population (1000 inhab)                                                            float64
# Population density (inhab/km2)_x                                                         float64
# GDP per capita (current US$/inhab)                                                       float64
# Human Development Index (HDI) [highest = 1] (-)                                          float64
# Groundwater: accounted outflow to other countries (10^9 m3/year)                         float64
# Produced municipal wastewater (km<sup>3</sup>/year or 10^9m<sup>3</sup>/year)            float64
# Collected municipal wastewater (km<sup>3</sup>/year or 10^9m<sup>3</sup>/year)           float64
# Treated municipal wastewater (km<sup>3</sup>/year or 10^9m<sup>3</sup>/year)             float64
# Number of municipal wastewater treatment facilities (-)                                  float64
# Capacity of the municipal wastewater treatment facilities (10^9 m3/yr)                   float64
# SDG 6.4.1. Water Use Efficiency (US$/m3)_x                                               float64
# Non-irrigated cultivated area drained (1000 ha)                                          float64
# Flood occurrence (WRI) (-)                                                               float64
# Population affected by water related disease (1000 inhabitants)                          float64
# Total renewable water resources per capita (m3/inhab/yr)                                 float64
# Agricultural water withdrawal (10^9 m3/year)                                             float64
# Industrial water withdrawal (km<sup>3</sup>/year or 10<sup>9</sup>m<sup>3</sup>/year)    float64
# Municipal water withdrawal (km<sup>3</sup>/year or 10<sup>9</sup>m<sup>3</sup>/year)     float64
# Total water withdrawal per capita (m<sup>3</sup>/year per inhabitant)                    float64
# MDG 7.5. Freshwater withdrawal as % of total renewable water resources (%)               float64
# SDG 6.4.2. Water Stress (%)                                                              float64
# SDG 6.4.1. Water Use Efficiency (US$/m3)_y                                               float64
# Resilience and securityStorage                                                           float64
# water productivity(industry)                                                             float64
# water productivity(Total agricultural production_US$)                                    float64
# dtype: object

# %%
# 转换数据类型
#data["rural water supply"]=data["rural water supply"].astype(float)
#data["urban water supply"]=data["urban water supply"].astype(float)
#data["water security index"]=data["water security index"].astype(float)
#data["RSA"]=data["RSA"].astype(float)
#data["Annual rate of change "]=data["Annual rate of change "].astype(float)

df_missing=data.isnull().sum().reset_index()
df_missing.columns=["feature","missing count"]
df_missing["missing percentage"]=df_missing["missing count"]/data.shape[0]
#df_missing["missing percentage"]=df_missing["missing percentage"].map(lambda x:"{:0.2%}".format(x))
df_missing.sort_values(by="missing count",ascending=True,inplace=True)
df_missing
# Out:
#                                               feature  missing count  \
# 0                                             country              0
# 31                       water productivity(industry)            114
# 8                       Urban population (1000 inhab)            125
# 7                       Rural population (1000 inhab)            125
# 9                    Population density (inhab/km2)_x            127
# 22  Total renewable water resources per capita (m3...            128
# 10                 GDP per capita (current US$/inhab)            129
# 32  water productivity(Total agricultural producti...            129
# 11    Human Development Index (HDI) [highest = 1] (-)            137
# 5                                              Health            142
# 25  Municipal water withdrawal (km<sup>3</sup>/yea...            142
# 26  Total water withdrawal per capita (m<sup>3</su...            145
# 24  Industrial water withdrawal (km<sup>3</sup>/ye...            145
# 23       Agricultural water withdrawal (10^9 m3/year)            145
# 6                                      2018 EPI SCORE            145
# 28                        SDG 6.4.2. Water Stress (%)            147
# 27  MDG 7.5. Freshwater withdrawal as % of total r...            147
# 20                         Flood occurrence (WRI) (-)            149
# 3                                  urban water supply            150
# 1                                                 RSA            152
# 18         SDG 6.4.1. Water Use Efficiency (US$/m3)_x            157
# 2                                  rural water supply            157
# 29         SDG 6.4.1. Water Use Efficiency (US$/m3)_y            157
# 30                    Resilience and securityStorage             161
# 12  Groundwater: accounted outflow to other countr...            170
# 4                                                 ARA            183
# 13  Produced municipal wastewater (km<sup>3</sup>/...            198
# 15  Treated municipal wastewater (km<sup>3</sup>/y...            212
# 16  Number of municipal wastewater treatment facil...            242
# 14  Collected municipal wastewater (km<sup>3</sup>...            259
# 17  Capacity of the municipal wastewater treatment...            267
# 19    Non-irrigated cultivated area drained (1000 ha)            283
# 21  Population affected by water related disease (...            293
#
#     missing percentage
# 0             0.000000
# 31            0.350769
# 8             0.384615
# 7             0.384615
# 9             0.390769
# 22            0.393846
# 10            0.396923
# 32            0.396923
# 11            0.421538
# 5             0.436923
# 25            0.436923
# 26            0.446154
# 24            0.446154
# 23            0.446154
# 6             0.446154
# 28            0.452308
# 27            0.452308
# 20            0.458462
# 3             0.461538
# 1             0.467692
# 18            0.483077
# 2             0.483077
# 29            0.483077
# 30            0.495385
# 12            0.523077
# 4             0.563077
# 13            0.609231
# 15            0.652308
# 16            0.744615
# 14            0.796923
# 17            0.821538
# 19            0.870769
# 21            0.901538

# %%
#More missing data than Asia data, so 0.35 change to 0.65
df=df_missing[df_missing["missing percentage"]<0.65]
df
data=data[df["feature"]]
data.head()
# Out:
#           country  water productivity(industry)  \
# 0     Afghanistan                      1.022643
# 1         Albania                     11.765478
# 2         Algeria                     20.235979
# 3  American Samoa                           NaN
# 4         Andorra                           NaN
#
#    Urban population (1000 inhab)  Rural population (1000 inhab)  \
# 0                       8971.472                      26558.609
# 1                       1740.032                       1190.155
# 2                      29770.610                      11547.532
# 3                            NaN                            NaN
# 4                         67.845                          9.120
#
#    Population density (inhab/km2)_x  \
# 0                         55.595553
# 1                        104.008979
# 2                         17.377711
# 3                               NaN
# 4                        163.831915
#
#    Total renewable water resources per capita (m3/inhab/yr)  \
# 0                                        1799.917253
# 1                                       10470.953680
# 2                                         281.885204
# 3                                                NaN
# 4                                        4098.648070
#
#    GDP per capita (current US$/inhab)  \
# 0                          605.557362
# 1                         4445.132198
# 2                         4051.244377
# 3                                 NaN
# 4                        39249.689020
#
#    water productivity(Total agricultural production_US$)  \
# 0                                       4.500000e+09
# 1                                       2.310000e+09
# 2                                       6.080000e+10
# 3                                                NaN
# 4                                       2.560000e+08
#
#    Human Development Index (HDI) [highest = 1] (-)      Health  ...  \
# 0                                            0.493  694.109542  ...
# 1                                            0.789    2.511507  ...
# 2                                            0.758  137.442788  ...
# 3                                              NaN         NaN  ...
# 4                                            0.852         NaN  ...
#
#    Flood occurrence (WRI) (-)  urban water supply          RSA  \
# 0                         3.7         95.90874286  62.26143773
# 1                         2.7          91.8354214  98.28801438
# 2                         2.8         95.44293244  89.67236867
# 3                         NaN                 NaN          NaN
# 4                         3.3                  99           99
#
#    SDG 6.4.1. Water Use Efficiency (US$/m3)_x  rural water supply  \
# 0                                    0.923778         57.32129212
# 1                                    6.656907         89.87517388
# 2                                   14.354620         88.69095651
# 3                                         NaN                 NaN
# 4                                         NaN                  99
#
#    SDG 6.4.1. Water Use Efficiency (US$/m3)_y  \
# 0                                    0.923778
# 1                                    6.656907
# 2                                   14.354620
# 3                                         NaN
# 4                                         NaN
#
#    Resilience and securityStorage   \
# 0                          2.00900
# 1                          4.03000
# 2                          8.61925
# 3                              NaN
# 4                              NaN
#
#    Groundwater: accounted outflow to other countries (10^9 m3/year)  \
# 0                                                NaN
# 1                                                0.0
# 2                                                0.1
# 3                                                NaN
# 4                                                NaN
#
#             ARA  \
# 0   2.730664253
# 1  -0.265874296
# 2   0.073382147
# 3           NaN
# 4           NaN
#
#   Produced municipal wastewater (km<sup>3</sup>/year or 10^9m<sup>3</sup>/year)
# 0                                                NaN
# 1                                              0.054
# 2                                              1.500
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 27 columns]

# %%
#data.to_csv("Ratesmalerthan35.csv",encoding="utf-8")
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)

# %%
listcolumn=data.columns
data_new=imputer.fit_transform(data[listcolumn[1:]])
data_new=pd.DataFrame(data_new)
data_new.columns=listcolumn[1:]
data_new.insert(0,"country",data["country"])
data_new
#data_new.to_csv("Imputed.csv",encoding="utf-8")
# Out:
#                    country  water productivity(industry)  \
# 0              Afghanistan                      1.022643
# 1                  Albania                     11.765478
# 2                  Algeria                     20.235979
# 3           American Samoa                     75.500347
# 4                  Andorra                    113.577426
# ..                     ...                           ...
# 320  Virgin Islands (U.S.)                     75.500347
# 321                Vietnam                      2.141214
# 322                  World                     20.611415
# 323                 Kosovo                     75.500347
# 324            Yemen, Rep.                      5.021698
#
#      Urban population (1000 inhab)  Rural population (1000 inhab)  \
# 0                       8971.47200                   26558.609000
# 1                       1740.03200                    1190.155000
# 2                      29770.61000                   11547.532000
# 3                      20681.74333                   17046.340835
# 4                         67.84500                       9.120000
# ..                             ...                            ...
# 320                    20681.74333                   17046.340835
# 321                     9081.02200                    5435.441800
# 322                     5850.78560                    6049.221400
# 323                    20681.74333                   17046.340835
# 324                     9081.02200                    5435.441800
#
#      Population density (inhab/km2)_x  \
# 0                           55.595553
# 1                          104.008979
# 2                           17.377711
# 3                          195.664495
# 4                          163.831915
# ..                                ...
# 320                        195.664495
# 321                         63.071263
# 322                         51.422622
# 323                        195.664495
# 324                         63.071263
#
#      Total renewable water resources per capita (m3/inhab/yr)  \
# 0                                          1799.917253
# 1                                         10470.953680
# 2                                           281.885204
# 3                                         17226.600056
# 4                                          4098.648070
# ..                                                 ...
# 320                                       17226.600056
# 321                                        9358.272748
# 322                                        7976.340722
# 323                                       17226.600056
# 324                                        9358.272748
#
#      GDP per capita (current US$/inhab)  \
# 0                            605.557362
# 1                           4445.132198
# 2                           4051.244377
# 3                          14951.892850
# 4                          39249.689020
# ..                                  ...
# 320                        14951.892850
# 321                         2014.239357
# 322                         4116.933947
# 323                        14951.892850
# 324                         2014.239357
#
#      water productivity(Total agricultural production_US$)  \
# 0                                         4.500000e+09
# 1                                         2.310000e+09
# 2                                         6.080000e+10
# 3                                         1.012615e+11
# 4                                         2.560000e+08
# ..                                                 ...
# 320                                       1.012615e+11
# 321                                       4.712600e+09
# 322                                       2.691800e+10
# 323                                       1.012615e+11
# 324                                       4.712600e+09
#
#      Human Development Index (HDI) [highest = 1] (-)      Health  ...  \
# 0                                           0.493000  694.109542  ...
# 1                                           0.789000    2.511507  ...
# 2                                           0.758000  137.442788  ...
# 3                                           0.710021  571.311294  ...
# 4                                           0.852000   25.539652  ...
# ..                                               ...         ...  ...
# 320                                         0.710021  571.311294  ...
# 321                                         0.807600  484.405530  ...
# 322                                         0.679800  170.589206  ...
# 323                                         0.710021  571.311294  ...
# 324                                         0.807600  484.405530  ...
#
#      Flood occurrence (WRI) (-)  urban water supply        RSA  \
# 0                      3.700000           95.908743  62.261438
# 1                      2.700000           91.835421  98.288014
# 2                      2.800000           95.442932  89.672369
# 3                      2.695455           94.158222  79.679500
# 4                      3.300000           99.000000  99.000000
# ..                          ...                 ...        ...
# 320                    2.695455           94.158222  79.679500
# 321                    2.300000           94.776894  74.723468
# 322                    2.200000           96.725155  85.208220
# 323                    2.695455           94.158222  79.679500
# 324                    2.300000           92.161550  80.974228
#
#      SDG 6.4.1. Water Use Efficiency (US$/m3)_x  rural water supply  \
# 0                                      0.923778           57.321292
# 1                                      6.656907           89.875174
# 2                                     14.354620           88.690957
# 3                                     46.862185           80.515798
# 4                                     38.590905           99.000000
# ..                                          ...                 ...
# 320                                   46.862185           80.515798
# 321                                   17.178177           70.380832
# 322                                    7.711055           66.477410
# 323                                   46.862185           80.515798
# 324                                   17.178177           70.380832
#
#      SDG 6.4.1. Water Use Efficiency (US$/m3)_y  \
# 0                                      0.923778
# 1                                      6.656907
# 2                                     14.354620
# 3                                     46.862185
# 4                                     38.590905
# ..                                          ...
# 320                                   46.862185
# 321                                   17.178177
# 322                                    7.711055
# 323                                   46.862185
# 324                                   17.178177
#
#      Resilience and securityStorage   \
# 0                           2.009000
# 1                           4.030000
# 2                           8.619250
# 3                          43.399025
# 4                           0.117064
# ..                               ...
# 320                        43.399025
# 321                        26.198266
# 322                        21.469621
# 323                        43.399025
# 324                        26.198266
#
#      Groundwater: accounted outflow to other countries (10^9 m3/year)  \
# 0                                             0.000000
# 1                                             0.000000
# 2                                             0.100000
# 3                                             0.266458
# 4                                             0.000000
# ..                                                 ...
# 320                                           0.266458
# 321                                           0.006000
# 322                                           0.006000
# 323                                           0.266458
# 324                                           0.006000
#
#           ARA  \
# 0    2.730664
# 1   -0.265874
# 2    0.073382
# 3    0.230218
# 4    0.090283
# ..        ...
# 320  0.230218
# 321  0.931179
# 322  0.745904
# 323  0.230218
# 324  0.612012
#
#      Produced municipal wastewater (km<sup>3</sup>/year or 10^9m<sup>3</sup>/year)
# 0                                             0.116600
# 1                                             0.054000
# 2                                             1.500000
# 3                                            61.178619
# 4                                             0.005880
# ..                                                 ...
# 320                                          61.178619
# 321                                           0.935760
# 322                                           0.903040
# 323                                          61.178619
# 324                                           0.935760
#
# [325 rows x 27 columns]

# %%
# Normalization

# remove the column of country name & water securty index
country_name = data_new.iloc[:,0]  #get the content of country name column

norm_data = data_new.drop('country',axis=1,inplace=False)
# print(norm_data_asia.dtypes)

#normalization
norm_df = norm_data.apply(lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)))
#print(norm_asia.head(5))

#add the column of country name
norm_df.insert(0,'country',country_name)
#print(norm_df.head(5))


# 2. min-max, SKL

# create a scaler object
#scaler2 = MinMaxScaler()
# fit and transform the data
#asia_norm = pd.DataFrame(scaler.fit_transform(df_cars), columns=df_cars.columns)



# output the preprocessed dataframe
norm_df.to_csv('average whole.csv')
